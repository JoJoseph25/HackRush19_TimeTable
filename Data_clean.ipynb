# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# REPLACE
#
# HS 507 - Humanism, Anti-humanism, and Posthumanism, with HS 507
#
# CG 604	Phenomenology, Embodiment and Concsiousness with CG 604
#
# HS 422	Classics of World Literature, Politics and Economics with HS 422
#
# ES 216 Signals, Systems, and Networks with ES 216
#
# to make split by "," column work

# %%
df=pd.read_csv("CourseRegNew.csv")

# %%
a=df["Course"].str.replace("HS 507 - Humanism, Anti-humanism, and Posthumanism","HS 507",regex=False)

# %%
b=a.str.replace("CG 604 - Phenomenology, Embodiment, And Consciousness","CG 604",regex=False)

# %%
c=b.str.replace("HS 422 - Classics of World Literature, Politics and Economics","HS 422",regex=False)

# %%
d=c.str.replace(" ES 216 - Signals, Systems and Networks","ES 216",regex=False)

# %%
df["Course"]=d

# %%
df.to_csv("RegCourses_mod.csv")

# %% [markdown]
# Count Number of People registered for each course

# %%
df=pd.read_csv("RegCourses_mod.csv")

# %%
df
# Out:
#                                   Name  Year                ProgramName  \
# 0     12e66d78c922ed1fa2cf4ce095856854  1821                     M.Tech
# 1     5e43c287605fc5af5f83b06c17348540  1331                       Ph.D
# 2     78a79233166838d50f3e9a29dd59a354  1811                     B.Tech
# 3     b8ccbace034850ef8ac28dce4dadc8d9  1821                     M.Tech
# 4     19f2e10346de798e1a8e836c7d21d84f  1852                        M.A
# 5     96511e1b8e7a00a225811e94788c94b1  1511                     B.Tech
# 6     2d98b351a7940e82b7886781e3f85f5d  1811                     B.Tech
# 7     c0c91a52257826bc4663fedcebfdd08e  1611                     B.Tech
# 8     42eb47fc44db1189f01f493a917c9362  1331                       Ph.D
# 9     5074983e7e2f4388cfcf40ee55e67f1f  1511                     B.Tech
# 10    5d1a95852276c4ee36320b7358eb8477  1711                     B.Tech
# 11    b36770382b9cb5da3c82c4e792555725  1435                       Ph.D
# ...

# %%
courses=df.iloc[:,4:13].copy()

# %%
Courses_taken=courses.stack().value_counts()

# %%
Courses_taken.to_csv("Courses_taken.csv")

# %%
programs=df.iloc[:,1:4]

# %%
programs.to_csv("Programs.csv")

# %%
Programs_count=programs.stack().value_counts()

# %%
Programs_count
# Out:
# B.Tech                             687
# Ph.D                               278
# M.Tech                             240
# Electrical Engineering             222
# Mechanical Engineering             197
# Civil Engineering                  194
# Chemical Engineering               171
# M.Sc                               166
# Materials Science & Engineering    142
# Comp Science & Engg                132
# Humanities and Social Science       67
# Chemistry                           67
# Mathematics                         66
# Physics                             63
# Biological Engineering              52
# M.A                                 44
# Cognitive Sciences                  43
# Earth Sciences                       5
# PGDIIT                               4
# B.Tech-M.Tech Dual Degree            3
# Earth System Science                 3
# Dual Major in B.Tech                 1
# B.Tech-M.Sc Dual Degree              1
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a.to_csv("Course_reg.csv")

# %% [markdown]
# Just keep subjects that are in the timetable.

# %%
courses=pd.read_csv("Just_course.csv")

# %%
courses.iloc[0:5,0:2]
# Out:
#   Courses
# 0  BE 402
# 1  BE 403
# 2  BE 601
# 3  BE 605
# 4  BE 608

# %%
students_ims=pd.read_csv("Courses_taken.csv")

# %%
students_ims.iloc[0:5,0:3]
# Out:
#   Courses  No_students
# 0  BE 402           99
# 1  BE 403            4
# 2  BE 601            4
# 3  BE 605           10
# 4  BE 608           13

# %%
student_in_courses=pd.merge(left=courses,right=students_ims, left_on='Courses', right_on='Courses')

# %%
student_in_courses
# Out:
#          Courses  No_students
# 0         BE 402           99
# 1         BE 403            4
# 2         BE 601            4
# 3         BE 605           10
# 4         BE 608           13
# 5         BE 611            9
# 6         BE 691            8
# 7         CE 202           21
# 8         CE 304           36
# 9         CE 305           33
# 10        CE 306           28
# 11        CE 307           33
# 12        CE 309           28
# 13        CE 402           20
# 14        CE 403           22
# 15        CE 602            9
# 16        CE 605           16
# 17        CE 613           13
# 18        CE 622           20
# 19        CE 629           12
# 20        CE 631           28
# 21        CG 501           18
# 22        CG 506           15
# 23        CG 507            7
# 24        CG 601           10
# 25        CG 604            5
# 26        CG 608            6
# 27        CH 202          191
# 28        CH 502            5
# 29        CH 508           28
# ...

# %%
student_in_courses.to_csv("Courses_num_stdnt.csv")

# %%
b=a["People"].as_matrix(columns=None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\joel\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3123             try:
# -> 3124                 return libindex.get_value_box(s, key)
#    3125             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-79119cf7f4a3> in <module>()
# ----> 1 b=a["People"].as_matrix(columns=None)
#
# c:\users\joel\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
# ...

# %%
plt.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-d6e8ffb9fe35> in <module>()
#       1 plt.plot(a)
# ----> 2 plt.show()
#
# c:\users\joel\appdata\local\programs\python\python36\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# c:\users\joel\appdata\local\programs\python\python36\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# c:\users\joel\appdata\local\programs\python\python36\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
# ...

# %%
plt.plot(b[:50])
plt.show()
